# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist

# %%
(X_train , y_train),(X_test,y_test) = mnist.load_data()

# %%
plt.imshow(X_train[0],cmap='gray')
plt.colorbar()

# %% [markdown]
# ### normalizing the train and test dataset

# %%
#normalizing the train dataset

X_train = tf.keras.utils.normalize(X_train,axis=1)

#normalizing the train dataset

X_test = tf.keras.utils.normalize(X_test,axis=1)

# %% [markdown]
# Build the model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Dropout

# %%
model = Sequential()

# %%
model.add(Flatten())

# %%
model.add(Dense(128,activation='relu'))
model.add(Dropout(.2))
model.add(Dense(128,activation='relu'))
model.add(Dropout(.2))
model.add(Dense(256,activation='relu'))
model.add(Dropout(.4))
model.add(Dense(256,activation='relu'))
model.add(Dropout(.4))

# %%
model.add(Dense(10,activation='softmax'))

# %% [markdown]
# Compile the model

# %%
model.compile(optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'])

# %%
history = model.fit(x=X_train, y=y_train,epochs=20, shuffle=True)
# Out:
# Train on 60000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.3837 - accuracy: 0.8835
# Epoch 2/20
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.1863 - accuracy: 0.9473
# Epoch 3/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.1495 - accuracy: 0.9579
# Epoch 4/20
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.1260 - accuracy: 0.9649
# Epoch 5/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1110 - accuracy: 0.9683
# Epoch 6/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.1056 - accuracy: 0.9705
# Epoch 7/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.0961 - accuracy: 0.9725
# Epoch 8/20
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.0901 - accuracy: 0.9747
# Epoch 9/20
# ...

# %%
test_loss,test_acc = model.evaluate(X_test,y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
predictions = model.predict([X_test])

# %%
import numpy as np
print(np.argmax(predictions[3000]))
# Out:
# 6

# %%
plt.imshow(X_test[3000])

# %%
import matplotlib.image as mpimg
img=mpimg.imread(r"C:\Users\Aditya\Desktop\VehicleDetailsAutomation\7.png")
imgplot = plt.imshow(img)
plt.show()

# %%
from keras.preprocessing import image
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# %%
import cv2
import numpy as np

# %%
images_array = []
img = cv2.imread(r"C:\Users\Aditya\Desktop\VehicleDetailsAutomation\7.png",cv2.IMREAD_GRAYSCALE)
img = cv2.resize(img,(28,28))
images_array.append([np.array(img)])

# %%
from numpy import asarray
photos = asarray(images_array)

# %%
photos.shape
# Out:
# (1, 1, 28, 28)

# %%
import tensorflow as tf
imggg = tf.keras.utils.normalize(photos,axis=1)

# %%
pre = model.predict(imggg)

# %%
print(np.argmax(pre))
# Out:
# 7

# %%
from tensorflow.keras.models import load_model
# serialize model to JSON
from tensorflow.keras.models import model_from_json
model_json = model.to_json()
with open("MNIST_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
# save model|
model.save_weights("MNIST_model.h5")

# %%
# load json and create model
from tensorflow.keras.models import model_from_json
json_file = open('MNIST_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("MNIST_model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
pre = loaded_model.predict(imggg)

# %%
print(np.argmax(pre))
# Out:
# 7

# %%
print(np.argmax(model.predict([X_test])))
# Out:
# 7

# %%
p= loaded_model.predict([X_test])

# %%
print(np.argmax(p[2000]))
# Out:
# 6

# %%
pyplot.imshow(X_test[2000])
